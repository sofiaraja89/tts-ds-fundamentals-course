# %% [markdown]
# Markdown cells can be used to add tex. Here are some examples of what you can do in a markdown cell.
#
# *apple*
# **apple**
#
# * apple
#    * apple
#       * strawberry
#
# 1. fruit
#    - strawberry
#       - seeds
#          -yum
#
# A quote:
# > Hello it's Sofia [link](https://commonmark.org/help/tutorial/10-nestedLists.html) was useful!
#
# # header 1
# ## header 2
# ### header 3
#
# \*asterisk that doesn't bold\*
#
# \\$5
#
# $e^{i\pi} + 1 = 0$
#
# \begin{equation}
# e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i
# \end{equation}
#
# ```python
# print "Hello World"
# ```
#
# ```javascript
# console.log("Hello World")
# ```
#
# | This | is   |
# |------|------|
# |  a   | table|
#
# ![pexels-abhishek-gaurav-794644.jpg](attachment:pexels-abhishek-gaurav-794644.jpg)
