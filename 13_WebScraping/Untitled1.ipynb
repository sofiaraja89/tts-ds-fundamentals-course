# %%
import requests

URL = "https://remote.co/remote-jobs/online-data-entry/"
page = requests.get(URL)

print(page.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js no-svg">
# <head>
# <title>
#   Online Data Entry Jobs - Remote.co</title><link rel="stylesheet" href="https://remote.co/wp-content/cache/min/1/56eda2aa34dcde1d39202bca32d8cfcb.css" media="all" data-minify="1" />
#
# <link rel="shortcut icon" href="https://remoteco.s3.amazonaws.com/wp-content/uploads/2017/02/retina_favicon_32.png" type="image/x-icon" />
#
# <meta charset="UTF-8">
# <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, user-scalable=0">
# <meta name="msvalidate.01" content="AAB4983B8CDBE98315805138D13BAB95" />
#
# <!--link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.3.1/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" crossorigin="anonymous"-->
#
# <meta name='robots' content='max-image-preview:large' />
#
# ...

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://remote.co/remote-jobs/online-data-entry/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

# %%
#results = soup.find(id="jobTypes") 
#<div class="location_sm">
 #<div class="card mb-2">
#div class="company_sm

# %%
#print(results.prettify())

# %%
job_elements = results.find_all("div", class_="card-body")

# %%
for job_element in job_elements:
    print(job_element, end="\n"*2)
